# %%
from binance.client import Client
import pandas as pd

# %%
api_key = ""
api_secret = ""

# %%
client = Client(api_key, api_secret)

# %%
exchange_info = client.get_exchange_info()

# %%
len(exchange_info['symbols'])
# Out:
# 2590

# %%
exchange_info['symbols']
# Out:
# [{'symbol': 'ETHBTC',
#   'status': 'TRADING',
#   'baseAsset': 'ETH',
#   'baseAssetPrecision': 8,
#   'quoteAsset': 'BTC',
#   'quotePrecision': 8,
#   'quoteAssetPrecision': 8,
#   'baseCommissionPrecision': 8,
#   'quoteCommissionPrecision': 8,
#   'orderTypes': ['LIMIT',
#    'LIMIT_MAKER',
#    'MARKET',
#    'STOP_LOSS_LIMIT',
#    'TAKE_PROFIT_LIMIT'],
#   'icebergAllowed': True,
#   'ocoAllowed': True,
#   'quoteOrderQtyMarketAllowed': True,
#   'allowTrailingStop': True,
#   'cancelReplaceAllowed': True,
#   'isSpotTradingAllowed': True,
#   'isMarginTradingAllowed': True,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '0.00001000',
#     'maxPrice': '922327.00000000',
#     'tickSize': '0.00001000'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.00010000',
#     'maxQty': '100000.00000000',
#     'stepSize': '0.00010000'},
#    {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#    {'filterType': 'MARKET_LOT_SIZE',
#     'minQty': '0.00000000',
# ...

# %%
exchange_info['symbols'][0]
# Out:
# {'symbol': 'ETHBTC',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'BTC',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00001000',
#    'maxPrice': '922327.00000000',
#    'tickSize': '0.00001000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '100000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '2198.53850291',
# ...

# %%
exchange_info['symbols'][0].keys()
# Out:
# dict_keys(['symbol', 'status', 'baseAsset', 'baseAssetPrecision', 'quoteAsset', 'quotePrecision', 'quoteAssetPrecision', 'baseCommissionPrecision', 'quoteCommissionPrecision', 'orderTypes', 'icebergAllowed', 'ocoAllowed', 'quoteOrderQtyMarketAllowed', 'allowTrailingStop', 'cancelReplaceAllowed', 'isSpotTradingAllowed', 'isMarginTradingAllowed', 'filters', 'permissions', 'defaultSelfTradePreventionMode', 'allowedSelfTradePreventionModes'])

# %%
columns = list(exchange_info['symbols'][0].keys())

# %%
columns
# Out:
# ['symbol',
#  'status',
#  'baseAsset',
#  'baseAssetPrecision',
#  'quoteAsset',
#  'quotePrecision',
#  'quoteAssetPrecision',
#  'baseCommissionPrecision',
#  'quoteCommissionPrecision',
#  'orderTypes',
#  'icebergAllowed',
#  'ocoAllowed',
#  'quoteOrderQtyMarketAllowed',
#  'allowTrailingStop',
#  'cancelReplaceAllowed',
#  'isSpotTradingAllowed',
#  'isMarginTradingAllowed',
#  'filters',
#  'permissions',
#  'defaultSelfTradePreventionMode',
#  'allowedSelfTradePreventionModes']

# %%
exchange_info['symbols'][0].values()
# Out:
# dict_values(['ETHBTC', 'TRADING', 'ETH', 8, 'BTC', 8, 8, 8, 8, ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], True, True, True, True, True, True, True, [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00001000', 'maxPrice': '922327.00000000', 'tickSize': '0.00001000'}, {'filterType': 'LOT_SIZE', 'minQty': '0.00010000', 'maxQty': '100000.00000000', 'stepSize': '0.00010000'}, {'filterType': 'ICEBERG_PARTS', 'limit': 10}, {'filterType': 'MARKET_LOT_SIZE', 'minQty': '0.00000000', 'maxQty': '2198.53850291', 'stepSize': '0.00000000'}, {'filterType': 'TRAILING_DELTA', 'minTrailingAboveDelta': 10, 'maxTrailingAboveDelta': 2000, 'minTrailingBelowDelta': 10, 'maxTrailingBelowDelta': 2000}, {'filterType': 'PERCENT_PRICE_BY_SIDE', 'bidMultiplierUp': '5', 'bidMultiplierDown': '0.2', 'askMultiplierUp': '5', 'askMultiplierDown': '0.2', 'avgPriceMins': 5}, {'filterType': 'NOTIONAL', 'minNotional': '0.00010000', 'applyMinToMarket': True, 'maxNotional': '9000000.00000000', '
# ...

# %%
df = pd.DataFrame.from_dict(exchange_info['symbols'])

# %%
df
# Out:
#         symbol   status baseAsset  baseAssetPrecision quoteAsset  \
# 0       ETHBTC  TRADING       ETH                   8        BTC
# 1       LTCBTC  TRADING       LTC                   8        BTC
# 2       BNBBTC  TRADING       BNB                   8        BTC
# 3       NEOBTC  TRADING       NEO                   8        BTC
# 4      QTUMETH  TRADING      QTUM                   8        ETH
# ...        ...      ...       ...                 ...        ...
# 2585   USDTCZK  TRADING      USDT                   8        CZK
# 2586    TAOBTC  TRADING       TAO                   8        BTC
# 2587   TAOUSDT  TRADING       TAO                   8       USDT
# 2588  TAOFDUSD  TRADING       TAO                   8      FDUSD
# 2589    TAOTRY  TRADING       TAO                   8        TRY
#
#       quotePrecision  quoteAssetPrecision  baseCommissionPrecision  \
# 0                  8                    8                        8
# ...

# %%
df.status.value_counts()
# Out:
# status
# BREAK      1355
# TRADING    1235
# Name: count, dtype: int64

# %%
df.isMarginTradingAllowed.value_counts()
# Out:
# isMarginTradingAllowed
# False    2011
# True      579
# Name: count, dtype: int64

# %%
df[df['status']=='TRADING']
# Out:
#         symbol   status baseAsset  baseAssetPrecision quoteAsset  \
# 0       ETHBTC  TRADING       ETH                   8        BTC
# 1       LTCBTC  TRADING       LTC                   8        BTC
# 2       BNBBTC  TRADING       BNB                   8        BTC
# 3       NEOBTC  TRADING       NEO                   8        BTC
# 4      QTUMETH  TRADING      QTUM                   8        ETH
# ...        ...      ...       ...                 ...        ...
# 2585   USDTCZK  TRADING      USDT                   8        CZK
# 2586    TAOBTC  TRADING       TAO                   8        BTC
# 2587   TAOUSDT  TRADING       TAO                   8       USDT
# 2588  TAOFDUSD  TRADING       TAO                   8      FDUSD
# 2589    TAOTRY  TRADING       TAO                   8        TRY
#
#       quotePrecision  quoteAssetPrecision  baseCommissionPrecision  \
# 0                  8                    8                        8
# ...

# %%
df[(df['status']=='TRADING') & (df['isMarginTradingAllowed'] == True)]
# Out:
#           symbol   status baseAsset  baseAssetPrecision quoteAsset  \
# 0         ETHBTC  TRADING       ETH                   8        BTC
# 1         LTCBTC  TRADING       LTC                   8        BTC
# 2         BNBBTC  TRADING       BNB                   8        BTC
# 3         NEOBTC  TRADING       NEO                   8        BTC
# 5         EOSETH  TRADING       EOS                   8        ETH
# ...          ...      ...       ...                 ...        ...
# 2562  PENDLEUSDC  TRADING    PENDLE                   8       USDC
# 2565       WUSDT  TRADING         W                   8       USDT
# 2572    TNSRUSDT  TRADING      TNSR                   8       USDT
# 2576    SAGAUSDT  TRADING      SAGA                   8       USDT
# 2587     TAOUSDT  TRADING       TAO                   8       USDT
#
#       quotePrecision  quoteAssetPrecision  baseCommissionPrecision  \
# 0                  8                    8                        8
# ...

# %%
df[(df['status']=='TRADING') & (df['isMarginTradingAllowed'] == True) & (df['quoteAsset']=='BTC')]
# Out:
#       symbol   status baseAsset  baseAssetPrecision quoteAsset  \
# 0     ETHBTC  TRADING       ETH                   8        BTC
# 1     LTCBTC  TRADING       LTC                   8        BTC
# 2     BNBBTC  TRADING       BNB                   8        BTC
# 3     NEOBTC  TRADING       NEO                   8        BTC
# 21    LRCBTC  TRADING       LRC                   8        BTC
# ...      ...      ...       ...                 ...        ...
# 2163   IDBTC  TRADING        ID                   8        BTC
# 2166  ARBBTC  TRADING       ARB                   8        BTC
# 2256  WLDBTC  TRADING       WLD                   8        BTC
# 2274  SEIBTC  TRADING       SEI                   8        BTC
# 2555  ENABTC  TRADING       ENA                   8        BTC
#
#       quotePrecision  quoteAssetPrecision  baseCommissionPrecision  \
# 0                  8                    8                        8
# 1                  8                    8                        8
# ...

# %%
df.to_csv("Binance_Spot_Pairs.csv", index=False)
