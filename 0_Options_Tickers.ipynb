# %%
import requests

# %%
import pandas

# %%
url = "https://eapi.binance.com/eapi/v1/time"

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
print(data)
# Out:
# {'serverTime': 1712893329833}

# %%
url = "https://eapi.binance.com/eapi/v1/exchangeInfo"

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
print(data)
# Out:
# {'timezone': 'UTC', 'serverTime': 1712893426684, 'optionContracts': [{'id': 1, 'baseAsset': 'SOL', 'quoteAsset': 'USDT', 'underlying': 'SOLUSDT', 'settleAsset': 'USDT'}, {'id': 2, 'baseAsset': 'BTC', 'quoteAsset': 'USDT', 'underlying': 'BTCUSDT', 'settleAsset': 'USDT'}, {'id': 3, 'baseAsset': 'ETH', 'quoteAsset': 'USDT', 'underlying': 'ETHUSDT', 'settleAsset': 'USDT'}, {'id': 4, 'baseAsset': 'BNB', 'quoteAsset': 'USDT', 'underlying': 'BNBUSDT', 'settleAsset': 'USDT'}, {'id': 5, 'baseAsset': 'XRP', 'quoteAsset': 'USDT', 'underlying': 'XRPUSDT', 'settleAsset': 'USDT'}, {'id': 6, 'baseAsset': 'DOGE', 'quoteAsset': 'USDT', 'underlying': 'DOGEUSDT', 'settleAsset': 'USDT'}], 'optionAssets': [{'id': 1, 'name': 'USDT'}], 'optionSymbols': [{'contractId': 3, 'expiryDate': 1719561600000, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '2465.7', 'maxPrice': '2995.1', 'tickSize': '0.1'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01', 'maxQty': '2500', 'stepSize': '0.01'}], 'id': 12020, 'symbol': 'ETH-240628-800-C', 'side': 'CALL', 'strikePrice': '800.00000000', 'underlying': 'ETHUSDT', 'unit': 1, 'makerFeeRate': '0.00030000', 'takerFeeRate': '0.00030000', 'minQty': '0.01', 'maxQty': '2500', 'initialMargin': '0.15000000', 'maintenanceMargin': '0.07500000', 'minInitialMargin': '0.10000000', 'minMaintenanceMargin': '0.05000000', 'priceScale': 1, 'quantityScale': 2, 'quoteAsset': 'USDT'}, {'contractId': 3, 'expiryDate': 1719561600000, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.1', 'maxPrice': '705.9', 'tickSize': '0.1'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01', 'maxQty': '2500', 'stepSize': '0.01'}], 'id': 12021, 'symbol': 'ETH-240628-800-P', 'side': 'PUT', 'strikePrice': '800.00000000', 'underlying': 'ETHUSDT', 'unit': 1, 'makerFeeRate': '0.00030000', 'takerFeeRate': '0.00030000', 'minQty': '0.01', 'maxQty': '2500', 'initialMargin': '0.15000000', 'maintenanceMargin': '0.07500000', 'minInitialMargin': '0.10000000', 'minMaintenanceMargin': '0.05000000', 'priceScale': 1, 'quantityScale': 2, 'quoteAsset': 'USDT'}, {'contractId': 3, 'expiryDate': 1719561600000, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '2065.7', 'maxPrice': '2595.1', 'tickSize': '0.1'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01', 'maxQty': '2500', 'stepSize': '0.01'}], 'id': 12022, 'symbol': 'ETH-240628-1200-C', 'side': 'CALL', 'strikePrice': '1200.00000000', 'underlying': 'ETHUSDT', 'unit': 1, 'makerFeeRate': '0.00030000', 'takerFeeRate': '0.00030000', 'minQty': '0.01', 'maxQty': '2500', 'initialMargin': '0.15000000', 'maintenanceMargin': '0.07500000', 'minInitialMargin': '0.10000000', 'minMaintenanceMargin': '0.05000000', 'priceScale': 1, 'quantityScale': 2, 'quoteAsset': 'USDT'}, {'contractId': 3, 'expiryDate': 1719561600000, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.1', 'maxPrice': '705.4', 'tickSize': '0.1'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01', 'maxQty': '2500', 'stepSize': '0.01'}], 'id': 12023, 'symbol': 'ETH-240628-1200-P', 'side': 'PUT', 'strikePrice': '1200.00000000', 'underlying': 'ETHUSDT', 'unit': 1, 'makerFeeRate': '0.00030000', 'takerFeeRate': '0.00030000', 'minQty': '0.01', 'maxQty': '2500', 'initialMargin': '0.15000000', 'maintenanceMargin': '0.07500000', 'minInitialMargin': '0.10000000', 'minMaintenanceMargin': '0.05000000', 'priceScale': 1, 'quantityScale': 2, 'quoteAsset': 'USDT'}, {'contractId': 3, 'expiryDate': 1719561600000, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '1765.9', 'maxPrice': '2295.3', 'tickSize': '0.1'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01', 'maxQty': '2500', 'stepSize': '0.01'}], 'id': 12024, 'symbol': 'ETH-240628-1500-C', 'side': 'CALL', 'strikePrice': '1500.00000000', 'underlying': 'ETHUSDT', 'unit': 1, 'makerFeeRate': '0.00030000', 'takerFeeRate': '0.00030000', 'minQty': '0.01', 'maxQty': '2500', 'initialMargin': '0.15000000', 'maintenanceMargin': '0.07500000', 'minInitialMargin': '0.10000000', 'minMaintenanceMargin': '0.05000000', 'priceScale': 1, 'quantitySc ...

# %%
len(data['optionContracts'])
# Out:
# 6

# %%
data.keys()
# Out:
# dict_keys(['timezone', 'serverTime', 'optionContracts', 'optionAssets', 'optionSymbols', 'rateLimits'])

# %%
df_options = pd.DataFrame.from_dict(data['optionSymbols'])

# %%
df_options
# Out:
#       contractId     expiryDate  \
# 0              3  1719561600000
# 1              3  1719561600000
# 2              3  1719561600000
# 3              3  1719561600000
# 4              3  1719561600000
# ...          ...            ...
# 1301           5  1713513600000
# 1302           5  1713513600000
# 1303           5  1713513600000
# 1304           5  1713513600000
# 1305           5  1713513600000
#
#                                                 filters     id  \
# 0     [{'filterType': 'PRICE_FILTER', 'minPrice': '2...  12020
# 1     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  12021
# 2     [{'filterType': 'PRICE_FILTER', 'minPrice': '2...  12022
# 3     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  12023
# 4     [{'filterType': 'PRICE_FILTER', 'minPrice': '1...  12024
# ...                                                 ...    ...
# 1301  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  38387
# 1302  [{'filterType': 'PRICE_FILTER', 'minPrice': '7...  38388
# 1303  [{'filterType': 'PRICE_FILTER', 'minPrice': '2...  38389
# 1304  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  38390
# 1305  [{'filterType': 'PRICE_FILTER', 'minPrice': '5...  38391
#
#                   symbol  side    strikePrice underlying  unit makerFeeRate  \
# 0       ETH-240628-800-C  CALL   800.00000000    ETHUSDT     1   0.00030000
# 1       ETH-240628-800-P   PUT   800.00000000    ETHUSDT     1   0.00030000
# 2      ETH-240628-1200-C  CALL  1200.00000000    ETHUSDT     1   0.00030000
# 3      ETH-240628-1200-P   PUT  1200.00000000    ETHUSDT     1   0.00030000
# 4      ETH-240628-1500-C  CALL  1500.00000000    ETHUSDT     1   0.00030000
# ...                  ...   ...            ...        ...   ...          ...
# 1301  XRP-240419-0.675-C  CALL     0.67500000    XRPUSDT   100   0.00030000
# 1302   XRP-240419-0.71-P   PUT     0.71000000    XRPUSDT   100   0.00030000
# 1303  XRP-240419-0.675-P   PUT     0.67500000    XRPUSDT   100   0.00030000
# 1304    XRP-240419-0.7-C  CALL     0.70000000    XRPUSDT   100   0.00030000
# 1305    XRP-240419-0.7-P   PUT     0.70000000    XRPUSDT   100   0.00030000
#
#      takerFeeRate minQty maxQty initialMargin maintenanceMargin  \
# 0      0.00030000   0.01   2500    0.15000000        0.07500000
# 1      0.00030000   0.01   2500    0.15000000        0.07500000
# 2      0.00030000   0.01   2500    0.15000000        0.07500000
# 3      0.00030000   0.01   2500    0.15000000        0.07500000
# 4      0.00030000   0.01   2500    0.15000000        0.07500000
# ...           ...    ...    ...           ...               ...
# 1301   0.00030000    0.1   4000    0.15000000        0.07500000
# 1302   0.00030000    0.1   4000    0.15000000        0.07500000
# 1303   0.00030000    0.1   4000    0.15000000        0.07500000
# 1304   0.00030000    0.1   4000    0.15000000        0.07500000
# 1305   0.00030000    0.1   4000    0.15000000        0.07500000
#
#      minInitialMargin minMaintenanceMargin  priceScale  quantityScale  \
# 0          0.10000000           0.05000000           1              2
# 1          0.10000000           0.05000000           1              2
# 2          0.10000000           0.05000000           1              2
# 3          0.10000000           0.05000000           1              2
# 4          0.10000000           0.05000000           1              2
# ...               ...                  ...         ...            ...
# 1301       0.10000000           0.05000000           3              1
# 1302       0.10000000           0.05000000           3              1
# 1303       0.10000000           0.05000000           3              1
# 1304       0.10000000           0.05000000           3              1
# 1305       0.10000000           0.05000000           3              1
#
#      quoteAsset
# 0          USDT
# 1          USDT
# 2          USDT
# 3          USDT
# 4          USDT
# ...         ...
# 1301       USDT
# 1302       USDT
# 1303       USDT
# 1304       USDT
# 1305       USDT
#
# [1306 rows x 20 columns]
